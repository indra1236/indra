# %% [markdown]
# <a href="https://colab.research.google.com/github/indra1236/indra/blob/main/UTS_Pengolahan_citra_digital_Soal_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import library
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files

# Upload gambar
uploaded = files.upload()

# Ambil nama file
image_path = list(uploaded.keys())[0]

# Baca gambar dalam grayscale
img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# Pastikan gambar terbaca
if img is None:
    print("Gagal membaca gambar!")
else:
    # =========================
    # TRANSFORMASI NEGATIF
    # =========================
    negative = 255 - img

    # =========================
    # TRANSFORMASI LOGARITMIK
    # =========================
    c = 255 / np.log(1 + np.max(img))
    log_image = c * np.log(1 + img)
    log_image = np.array(log_image, dtype=np.uint8)

    # =========================
    # TAMPILKAN HASIL
    # =========================
    titles = ['Citra Asli', 'Negatif', 'Logaritmik']
    images = [img, negative, log_image]

    plt.figure(figsize=(12, 8))

    for i in range(3):
        plt.subplot(3, 3, i+1)
        plt.imshow(images[i], cmap='gray')
        plt.title(titles[i])
        plt.axis('off')

        # Histogram
        plt.subplot(3, 3, i+4)
        plt.hist(images[i].ravel(), bins=256)
        plt.title('Histogram ' + titles[i])

    plt.tight_layout()
    plt.show()
# Out:
#      <input type="file" id="files-234e064e-c286-48e6-a789-2f1c7c4d9042" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-234e064e-c286-48e6-a789-2f1c7c4d9042">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
